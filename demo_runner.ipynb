# %% [markdown]
# # Demo Runner

# %% [markdown]
# ## Steps to execute
# 1. Clone the repository
# 2. Download all the requirements
# 3. Connect the google drive with the weights and datasets
# 4. Copy datasets and weights
# 5. Insert the hugging face token
# 6. Launch the demo

# %%
# !git clone https://github.com/hadi-ibra/SICK_Summarization.git

# %cd SICK_Summarization

# %%
# %%capture
# !pip install -r requirements.txt

# !pip install -U spacy
# !pip install accelerate -U
# !python -m spacy download en_core_web_s

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import shutil

# %%
# COMET data with idioms
source_directory = '<ADD_YOUR_PATH>'
destination_directory = '/content/SICK_Summarization/src/data/COMET_data'

shutil.copytree(source_directory, destination_directory)

# %%
# DialogSum data with idioms
source_directory = '<ADD_YOUR_PATH>'
destination_directory = '/content/SICK_Summarization/src/data/DialogSum_Data'

shutil.copytree(source_directory, destination_directory)

# %%
# Copy SICK weights for the run
source_directory = '<ADD_PATH_TO_SICK_WEIGTH>'
destination_directory = '/content/SICK_Summarization/sick_best'

shutil.copytree(source_directory, destination_directory)

# %%
# Copy Idiom SICK weights for the run
source_directory = '<ADD_PATH_TO_IDIOM_SICK_WEIGTH>'
destination_directory = '/content/SICK_Summarization/idiom_sick_best'

shutil.copytree(source_directory, destination_directory)

# %%
# !wandb disabled
# !HUGGING_FACE_TOKEN=<ADD_YOUR_TOKEN> python demo.py
